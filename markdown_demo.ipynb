# %% [markdown]
# # Markdown Formatting in Jupyter Notebook
#
# This notebook demonstrates how to use headings, lists, and code formatting in Markdown cells.

# %% [markdown]
# ## Features Demonstrated
#
# - Headings for structure
# - Unordered lists for explanations
# - Ordered lists for steps
#
# ### Steps to Follow
#
# 1. Write Markdown text
# 2. Add structure using headings
# 3. Use lists for clarity

# %% [markdown]
# ## Code Formatting
#
# Inline code example: `print("hello")`
#
# Code block example:
#
# ```python
# x = 5
# y = 10
# print(x + y)

# %% [markdown]
# ---
#
# ### 🔵 Cell 4 → Code
# ```python
# print("Markdown demo working")

# %% [markdown]
# ## Explanation
#
# - Markdown cells are used for explanation
# - Code cells are used for execution
# - Combining both improves readability and structure
