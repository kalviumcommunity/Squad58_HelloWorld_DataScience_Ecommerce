# %% [markdown]
# # Code vs Markdown Demonstration
#
# This notebook demonstrates the difference between Code cells and Markdown cells in Jupyter Notebook.

# %% [markdown]
# ## Code Cell Example
#
# The following cell runs Python code and produces output.

# %%
x = 5
y = 10
print("Sum:", x + y)
# Out:
# Sum: 15

# %% [markdown]
# ## Explanation
#
# The above code adds two numbers and prints the result.

# %%
print("This is a code cell")
# Out:
# This is a code cell

# %% [markdown]
# ## Conclusion
#
# - Code cells are used to run Python code
# - Markdown cells are used for explanations
# - Separating them improves readability and collaboration
